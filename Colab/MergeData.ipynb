# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

# %%
df_GD = pd.read_csv("/content/drive/MyDrive/HK8/DACN2/Colab/BaoChinhPhu/giaoduc.csv")
df_TT = pd.read_csv("/content/drive/MyDrive/HK8/DACN2/Colab/BaoChinhPhu/thethao.csv")
df_KT = pd.read_csv("/content/drive/MyDrive/HK8/DACN2/Colab/BaoChinhPhu/kinhte.csv")
df_CT = pd.read_csv("/content/drive/MyDrive/HK8/DACN2/Colab/BaoChinhPhu/chinhtri.csv")
df_DL = pd.read_csv("/content/drive/MyDrive/HK8/DACN2/Colab/BaoChinhPhu/dulich.csv")
df_KH = pd.read_csv("/content/drive/MyDrive/HK8/DACN2/Colab/BaoChinhPhu/khoahoc.csv")
df_YT = pd.read_csv("/content/drive/MyDrive/HK8/DACN2/Colab/BaoChinhPhu/yte.csv")
df_PL = pd.read_csv("/content/drive/MyDrive/HK8/DACN2/Colab/BaoChinhPhu/phapluat.csv")

df_Fake_1 = pd.read_csv("/content/drive/MyDrive/HK8/DACN2/Colab/Fake_News/fake.csv")
df_Fake_2 = pd.read_csv("/content/drive/MyDrive/HK8/DACN2/Colab/Fake_News/public_train.csv")
df_Fake_3 = pd.read_csv("/content/drive/MyDrive/HK8/DACN2/Colab/Fake_News/vn_news_226_tlfr.csv")
df_Fake_4 = pd.read_excel("/content/drive/MyDrive/HK8/DACN2/Colab/Fake_News/warmup_training_dataset.xlsx")

# %%
df_Fake_2
# Out:
#         id                         user_name  \
# 0        1  389c669730cb6c54314a46be785cea42
# 1        2  775baa6d037b6d359b229a656eaeaf08
# 2        3  b9f3394d2aff86d85974f5040c401f08
# 3        4  808e278b22ec6b96f2faf7447d10cd8e
# 4        5  f81bdd6d8be4c5f64bb664214e47aced
# ...    ...                               ...
# 4367  4368  20933f35ef5d22b4d8193cc269c8ff1e
# 4368  4369  a117312f796a22e364b8e241b8cb91eb
# 4369  4370  547ba1b4f95ec07f2cdada24a6eec693
# 4370  4371  acb4a36d6247a0c89dac880725b2b3a0
# 4371  4372  3deabd01107da8ae2a29ca03483714d1
#
#                                            post_message timestamp_post  \
# 0     THĂNG CẤP BẬC HÀM ĐỐI VỚI 2 CÁN BỘ, CHIẾN SỸ H...     1585945439
# 1                                                 <URL>   1588939166.0
# 2     TƯ VẤN MÙA THI: Cách nộp hồ sơ để trúng tuyển ...     1591405213
# 3     Cơ quan Cạnh tranh và Thị trường Anh quyết địn...     1592023613
# ...

# %%
df_Fake_3
# Out:
#                                                   text  label
# 0    Thủ tướng Abe cúi đầu xin lỗi vì hành động phi...      1
# 1    Thủ tướng Nhật cúi đầu xin lỗi vì tinh thần ph...      1
# 2    Choáng! Cơ trưởng đeo khăn quàng quẩy banh nóc...      1
# 3    Chưa bao giờ nhạc Kpop lại dễ hát đến thế!!!\n...      1
# 4    Đại học Hutech sẽ áp dụng cải cách "Tiếq Việt"...      1
# ..                                                 ...    ...
# 221  Chuyện về chàng sinh viên Luật - Kiện tướng Lê...      0
# 222  Tiền đạo Malaysia: “Tôi đã có cách vượt qua hà...      0
# 223  CÁC BẠN TIN KHÔNG MIỄN PHÍ 100% CHIẾN DỊCH QUẢ...      1
# 224  Thân gởi các bạn yêu quý! tôi nghĩ các bạn nên...      1
# 225  Cho e giải thích thắc mắc của a Dương lo lắng ...      1
#
# [226 rows x 2 columns]

# %%
df_Fake_4
# Out:
#       id            user_name  \
# 0      0  2167074723833126912
# 1      1  7368497547812410368
# 2      2 -5754142625280308224
# 3      3  4177935308849652224
# 4      4  5540309800745996288
# ..   ...                  ...
# 795  795  2490795936720330752
# 796  796  1846872478075934976
# 797  797 -4723502351165939712
# 798  798  7717037201428829184
# 799  799 -8318346087637567488
#
#                                           post_message  timestamp_post  \
# 0    Cần các bậc phụ huynh xã Ngũ Thái lên tiếng, k...    1.584426e+09
# 1    KÊU GỌI ĂN CHAY CẦU NGUYỆN XIN CHÚA CỨU KHỎI D...    1.581363e+09
# 2    Giàn khoan dầu khí gặp sự cố, chết người!\n\nG...    1.587042e+09
# 3    Thuận Lợi có ca dương tính CV19 rồi đó, mọi ng...    1.596449e+09
# 4    Sa Pa cho 9 người khách nước ngoài đi cùng chu...    1.583548e+09
# ..                                                 ...             ...
# 795  Định cư gần 60 năm, trong đó 20 năm bị "treo" ...    1.587537e+09
# ...

# %%
df_filtered_2 = df_Fake_2[df_Fake_2['label'] == 1][['post_message', 'label']]
df_filtered_2
# Out:
#                                            post_message  label
# 10    Trong 1 vụ xô xát nhỏ thôi, em trai này bị bắt...      1
# 11    Thông điệp của bức tranh mang tên là: “Khải Ho...      1
# 13    Cấm vô thời hạn tất cả các chuyến bay từ Việt ...      1
# 15    WHO còn có nghĩa khác là "ai". Vậy ai chịu trá...      1
# 28    Ngày Hòa bình và Môi trường Việt nam\n\nThay v...      1
# ...                                                 ...    ...
# 4349  Xong...! Ning Giang Toang rồi\n\nNinh Giang dí...      1
# 4352  DU KHÁCH TRUNG QUỐC ĐẦU TIÊN CHẾT VÌ VIRUS COR...      1
# 4363  Tin từ Phó Chủ Tịch UBND TPHCM Lê Thanh Liêm.\...      1
# 4369  Lời cảnh tỉnh cho các thanh niên dân TỔ...tốc ...      1
# 4370  Đến bây giờ mới biết chỉ cần học lái xe hạng B...      1
#
# [734 rows x 2 columns]

# %%
df_filtered_2 = df_filtered_2.rename(columns={'post_message': 'content'})
df_filtered_2
# Out:
#                                                 content  label
# 10    Trong 1 vụ xô xát nhỏ thôi, em trai này bị bắt...      1
# 11    Thông điệp của bức tranh mang tên là: “Khải Ho...      1
# 13    Cấm vô thời hạn tất cả các chuyến bay từ Việt ...      1
# 15    WHO còn có nghĩa khác là "ai". Vậy ai chịu trá...      1
# 28    Ngày Hòa bình và Môi trường Việt nam\n\nThay v...      1
# ...                                                 ...    ...
# 4349  Xong...! Ning Giang Toang rồi\n\nNinh Giang dí...      1
# 4352  DU KHÁCH TRUNG QUỐC ĐẦU TIÊN CHẾT VÌ VIRUS COR...      1
# 4363  Tin từ Phó Chủ Tịch UBND TPHCM Lê Thanh Liêm.\...      1
# 4369  Lời cảnh tỉnh cho các thanh niên dân TỔ...tốc ...      1
# 4370  Đến bây giờ mới biết chỉ cần học lái xe hạng B...      1
#
# [734 rows x 2 columns]

# %%
df_filtered_3 = df_Fake_3[df_Fake_3['label'] == 1][['text', 'label']]
df_filtered_3 = df_filtered_3.rename(columns={'text': 'content'})
df_filtered_3
# Out:
#                                                content  label
# 0    Thủ tướng Abe cúi đầu xin lỗi vì hành động phi...      1
# 1    Thủ tướng Nhật cúi đầu xin lỗi vì tinh thần ph...      1
# 2    Choáng! Cơ trưởng đeo khăn quàng quẩy banh nóc...      1
# 3    Chưa bao giờ nhạc Kpop lại dễ hát đến thế!!!\n...      1
# 4    Đại học Hutech sẽ áp dụng cải cách "Tiếq Việt"...      1
# ..                                                 ...    ...
# 98   Chữa hết bệnh câm cho vợ, người chồng cay đắng...      1
# 99   YÊU RÂU XANH (P51): Câu chuyện động trời sau t...      1
# 223  CÁC BẠN TIN KHÔNG MIỄN PHÍ 100% CHIẾN DỊCH QUẢ...      1
# 224  Thân gởi các bạn yêu quý! tôi nghĩ các bạn nên...      1
# 225  Cho e giải thích thắc mắc của a Dương lo lắng ...      1
#
# [103 rows x 2 columns]

# %%
df_filtered_4 = df_Fake_4[df_Fake_4['label'] == 1][['post_message', 'label']]
df_filtered_4 = df_filtered_4.rename(columns={'post_message': 'content'})
df_filtered_4
# Out:
#                                                content  label
# 0    Cần các bậc phụ huynh xã Ngũ Thái lên tiếng, k...      1
# 1    KÊU GỌI ĂN CHAY CẦU NGUYỆN XIN CHÚA CỨU KHỎI D...      1
# 2    Giàn khoan dầu khí gặp sự cố, chết người!\n\nG...      1
# 3    Thuận Lợi có ca dương tính CV19 rồi đó, mọi ng...      1
# 4    Sa Pa cho 9 người khách nước ngoài đi cùng chu...      1
# ..                                                 ...    ...
# 195  Căn biệt thự trăm tỉ toàn gỗ của Chủ tịch tỉnh...      1
# 196  Hót hót hót Toamit Thẻ đeo chống virus, kháng ...      1
# 197  TP.HCM bị phong tỏa từ ngày 28-3... Phong tỏa ...      1
# 198  VTV1 CŨNG ĐÃ NÓI RỒI NÊN MỌI NGƯỜI CỨ LÀM NHA....      1
# 199  Thêm nghi vấn virus Corona mới xuất phát từ mộ...      1
#
# [200 rows x 2 columns]

# %%
df_Fake = pd.concat([df_Fake_1, df_filtered_2,df_filtered_3,df_filtered_4], ignore_index=True)
df_Fake
# Out:
#                                                 content  label
# 0     Từ đầu tháng 4/2023 đến nay, một số khu vực ở ...      1
# 1     Qua xác minh, Trung tâm Xử lý tin giả Việt Nam...      1
# 2     Qua tiếp nhận phản ánh và tiến hành xác minh, ...      1
# 3     Qua công tác rà soát và tiếp nhận thông tin, T...      1
# 4     Trung tâm Xử lý Tin giả Việt Nam (VAFC) phát h...      1
# ...                                                 ...    ...
# 1101  Căn biệt thự trăm tỉ toàn gỗ của Chủ tịch tỉnh...      1
# 1102  Hót hót hót Toamit Thẻ đeo chống virus, kháng ...      1
# 1103  TP.HCM bị phong tỏa từ ngày 28-3... Phong tỏa ...      1
# 1104  VTV1 CŨNG ĐÃ NÓI RỒI NÊN MỌI NGƯỜI CỨ LÀM NHA....      1
# 1105  Thêm nghi vấn virus Corona mới xuất phát từ mộ...      1
#
# [1106 rows x 2 columns]

# %%
df_Real = pd.concat([df_GD,df_TT,df_KT,df_CT,df_DL,df_KH,df_YT,df_PL], ignore_index=True)
df_Real
# Out:
#                                                 content  label
# 0     Theo đó, 2 bên đã trao đổi kinh nghiệm đưa thự...      0
# 1     Sau hai năm phải tạm ngưng vì đại dịch, Giải b...      0
# 2     Trường Đại học Kinh tế Quốc dân đã công bố Đề ...      0
# 3      Ngày 31/3, chương trình truyền hình “Chào tiế...      0
# 4     Ngày 31/3, Khoa Các khoa học liên ngành (SIS, ...      0
# ...                                                 ...    ...
# 6093  Trước đó, Cơ quan Cảnh sát điều tra Công an tỉ...      0
# 6094  Ngày 3/3, Thiếu tá Nguyễn Kim Trung, Trưởng Ph...      0
# 6095  Tại Lễ ra quân, Đại tá Nguyễn Văn Tăng, Phó Gi...      0
# 6096  Ở đâu luật ‘bất thành văn’ khi đi đăng kiểm? C...      0
# 6097  Sau gần 2 ngày xét xử, ngày 2/3, TAND tỉnh Điệ...      0
#
# [6098 rows x 2 columns]

# %%
df = pd.concat([df_Fake, df_Real], ignore_index=True)
df
# Out:
#                                                 content  label
# 0     Từ đầu tháng 4/2023 đến nay, một số khu vực ở ...      1
# 1     Qua xác minh, Trung tâm Xử lý tin giả Việt Nam...      1
# 2     Qua tiếp nhận phản ánh và tiến hành xác minh, ...      1
# 3     Qua công tác rà soát và tiếp nhận thông tin, T...      1
# 4     Trung tâm Xử lý Tin giả Việt Nam (VAFC) phát h...      1
# ...                                                 ...    ...
# 7199  Trước đó, Cơ quan Cảnh sát điều tra Công an tỉ...      0
# 7200  Ngày 3/3, Thiếu tá Nguyễn Kim Trung, Trưởng Ph...      0
# 7201  Tại Lễ ra quân, Đại tá Nguyễn Văn Tăng, Phó Gi...      0
# 7202  Ở đâu luật ‘bất thành văn’ khi đi đăng kiểm? C...      0
# 7203  Sau gần 2 ngày xét xử, ngày 2/3, TAND tỉnh Điệ...      0
#
# [7204 rows x 2 columns]

# %%
df.isna().sum()
# Out:
# content    32
# label       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7204 entries, 0 to 7203
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   content  7172 non-null   object
#  1   label    7204 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 112.7+ KB

# %%
df = df.dropna()
df
# Out:
#                                                 content  label
# 0     Từ đầu tháng 4/2023 đến nay, một số khu vực ở ...      1
# 1     Qua xác minh, Trung tâm Xử lý tin giả Việt Nam...      1
# 2     Qua tiếp nhận phản ánh và tiến hành xác minh, ...      1
# 3     Qua công tác rà soát và tiếp nhận thông tin, T...      1
# 4     Trung tâm Xử lý Tin giả Việt Nam (VAFC) phát h...      1
# ...                                                 ...    ...
# 7199  Trước đó, Cơ quan Cảnh sát điều tra Công an tỉ...      0
# 7200  Ngày 3/3, Thiếu tá Nguyễn Kim Trung, Trưởng Ph...      0
# 7201  Tại Lễ ra quân, Đại tá Nguyễn Văn Tăng, Phó Gi...      0
# 7202  Ở đâu luật ‘bất thành văn’ khi đi đăng kiểm? C...      0
# 7203  Sau gần 2 ngày xét xử, ngày 2/3, TAND tỉnh Điệ...      0
#
# [7172 rows x 2 columns]

# %%
df = df[(df['content'].apply(lambda x: len(str(x))) >= 80) & (df['content'].apply(lambda x: len(str(x))) < 8000)]
df
# Out:
#                                                 content  label
# 0     Từ đầu tháng 4/2023 đến nay, một số khu vực ở ...      1
# 1     Qua xác minh, Trung tâm Xử lý tin giả Việt Nam...      1
# 2     Qua tiếp nhận phản ánh và tiến hành xác minh, ...      1
# 3     Qua công tác rà soát và tiếp nhận thông tin, T...      1
# 4     Trung tâm Xử lý Tin giả Việt Nam (VAFC) phát h...      1
# ...                                                 ...    ...
# 7199  Trước đó, Cơ quan Cảnh sát điều tra Công an tỉ...      0
# 7200  Ngày 3/3, Thiếu tá Nguyễn Kim Trung, Trưởng Ph...      0
# 7201  Tại Lễ ra quân, Đại tá Nguyễn Văn Tăng, Phó Gi...      0
# 7202  Ở đâu luật ‘bất thành văn’ khi đi đăng kiểm? C...      0
# 7203  Sau gần 2 ngày xét xử, ngày 2/3, TAND tỉnh Điệ...      0
#
# [6654 rows x 2 columns]

# %%
df.label.value_counts()
# Out:
# 0    5611
# 1    1043
# Name: label, dtype: int64

# %%
df = df.drop_duplicates()
df
# Out:
#                                                 content  label
# 0     Từ đầu tháng 4/2023 đến nay, một số khu vực ở ...      1
# 1     Qua xác minh, Trung tâm Xử lý tin giả Việt Nam...      1
# 2     Qua tiếp nhận phản ánh và tiến hành xác minh, ...      1
# 3     Qua công tác rà soát và tiếp nhận thông tin, T...      1
# 4     Trung tâm Xử lý Tin giả Việt Nam (VAFC) phát h...      1
# ...                                                 ...    ...
# 7103  Phó Thủ tướng yêu cầu Ủy ban nhân dân tỉnh Quả...      0
# 7104  Theo Báo Khánh Hòa, chiều 13/4, ông Nguyễn Sỹ ...      0
# 7105  Mục đích của việc tổng kết thi hành Luật Hòa g...      0
# 7106  Theo Cục Cảnh sát Phòng cháy, chữa cháy và Cứu...      0
# 7107  Báo cáo tại phiên thẩm định, ông Trịnh Đức Trọ...      0
#
# [5177 rows x 2 columns]

# %%
df.label.value_counts()
# Out:
# 0    4254
# 1     923
# Name: label, dtype: int64

# %%
def split_word(x):return len(x.split())
len_text = df['content'].apply(split_word)
len_text.describe()
# Out:
# count    5177.000000
# mean      641.027043
# std       403.965216
# min        16.000000
# 25%       345.000000
# 50%       589.000000
# 75%       902.000000
# max      1769.000000
# Name: content, dtype: float64

# %%
df.to_csv('/content/drive/MyDrive/HK8/DACN2/Colab/BaoChinhPhu/TongHop.csv', encoding='utf-8', index=False)
